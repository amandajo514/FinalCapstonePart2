# %% [markdown]
# # Instagram Influencers _ Data Cleanup, Consolidation, & Tableau Preperation

# %% [markdown]
# #### Part I: Importing the libraries & pulling in the datasets.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_data1 = pd.read_csv('data/top_200_instagrammers.csv')

# %%
df_data2 = pd.read_csv('data/Top_Influencers.csv')

# %% [markdown]
# #### Part II: Cleaning & consolidating the datasets.

# %%
pd.set_option('display.max_columns', None)

df_data1.head()
# Out:
#       Username Channel Name Country                                    Url  \
# 0    cristiano    cristiano      ES    https://www.instagram.com/cristiano
# 1  kyliejenner  kyliejenner      US  https://www.instagram.com/kyliejenner
# 2     leomessi     leomessi     NaN     https://www.instagram.com/leomessi
# 3  selenagomez  selenagomez      US  https://www.instagram.com/selenagomez
# 4      therock      therock      US      https://www.instagram.com/therock
#
#   Main topic Main video category         Likes    Likes Avg.  Posts  \
# 0     Sports              Sports  2.287645e+10  8.671953e+06   3328
# 1        NaN                 NaN  4.304855e+10  8.296736e+06   6921
# 2        NaN                 NaN  4.670492e+09  6.895178e+06    875
# 3        NaN                 NaN  8.442643e+09  6.252711e+06   1835
# 4        NaN                 NaN  9.562231e+09  1.874151e+06   6660
#
#    Followers  Boost Index  Comments Avg.    Views Avg.  Avg. 1 Day  \
# 0  465027234           92   51758.330927  1.700949e+07         NaN
# 1  356687629           91   47534.120961  2.287547e+07         NaN
# 2  347032978           90   47044.540305  1.176160e+07         NaN
# 3  334551681           93   39167.115727  1.072397e+07         NaN
# 4  327064138           91    8529.747043  5.413831e+06         NaN
#
#    Avg. 3 Day  Avg. 7 Day   Avg. 14 Day   Avg. 30 Day  Engagement Rate  \
# 0         NaN   3321113.0  5.327340e+06  6.948659e+06         0.014916
# 1         NaN   1223002.0  2.196528e+06  4.692459e+06         0.017617
# 2   4810554.0   3199807.0  5.359469e+06  5.668454e+06         0.015534
# 3         NaN         NaN  2.340219e+06  2.340219e+06         0.013913
# 4         NaN    713970.0  1.101339e+06  1.165227e+06         0.004426
#
#    Engagement Rate (60 Days)
# 0                   0.015903
# 1                   0.016189
# 2                   0.019045
# 3                   0.007720
# 4                   0.003723

# %%
df_data1.shape
# Out:
# (200, 20)

# %%
df_data2.head()
# Out:
#    Rank   Channel Info  Influence Score Followers Avg. Likes Posts  \
# 0     1    \ncristiano               92    485.2m       8.7m  3.4k
# 1     2    kyliejenner               91    370.7m       8.2m  7.0k
# 2     3     \nleomessi               90    363.9m       6.7m   915
# 3     4  \nselenagomez               93    348.8m       6.1m  1.9k
# 4     5      \ntherock               91    339.4m       1.8m  6.8k
#
#    60-Day Eng Rate New Post Avg. Likes Total Likes Country Or Region
# 0            0.013                6.3m       29.1b             Spain
# 1            0.014                5.0m       57.4b     United States
# 2            0.010                3.5m        6.1b               NaN
# 3            0.005                1.7m       11.4b     United States
# 4            0.003              932.0k       12.6b     United States

# %%
df_data2.shape
# Out:
# (200, 10)

# %% [markdown]
# ###### ** Both datasets have 200 rows. Dataset 1 has 20 columns and dataset 2 has 10 columns.

# %%
df_data1.dtypes
# Out:
# Username                      object
# Channel Name                  object
# Country                       object
# Url                           object
# Main topic                    object
# Main video category           object
# Likes                        float64
# Likes Avg.                   float64
# Posts                          int64
# Followers                      int64
# Boost Index                    int64
# Comments Avg.                float64
# Views Avg.                   float64
# Avg. 1 Day                   float64
# Avg. 3 Day                   float64
# Avg. 7 Day                   float64
# Avg. 14 Day                  float64
# Avg. 30 Day                  float64
# Engagement Rate              float64
# Engagement Rate (60 Days)    float64
# dtype: object

# %%
df_data2.dtypes
# Out:
# Rank                     int64
# Channel Info            object
# Influence Score          int64
# Followers               object
# Avg. Likes              object
# Posts                   object
# 60-Day Eng Rate        float64
# New Post Avg. Likes     object
# Total Likes             object
# Country Or Region       object
# dtype: object

# %% [markdown]
# ###### ** Channel Name and Channel Info can be consolidated bc they are both objects and both list the channel name. Have to change column names to match before combining.
# ###### ** Followers and Followers can be combined but only after converting both to int since its a number that we want to use for calculations. Have to change column names to match before combining.
# ###### ** Country and Country Or Region can be combined bc they are both objects and both list the country in which the insta influencer resides. Have to change column names to match before combining.
# ###### ** Likes Avg. and Avg. Likes can be combined but only after converting both to int since its a number that we want to use for calculations. Have to change column names to match before combining.
# ###### ** Posts and Posts can be combined but only after converting both to int since its a number that we want to use for calculations. Have to change column names to match before combining.
# ###### ** Engagement Rate (60 Days) & 60-Day Eng Rate can be combined bc both are floats and both list the 60 day engagement rate. Have to change column names to match before combining.
# ###### ** Likes and Total Likes can cbe combined but only after converting both to int since its a number that we want to use for calculations. Have to change column names to match before combining.

# %%
# First, changing dtypes to match:

# %%
df_data2['Total Likes'] = pd.to_numeric(df_data2['Total Likes'].str.replace('[^\d.]', ''), errors='coerce').astype(float).astype('Int64')

# %%
df_data2['Followers'] = pd.to_numeric(df_data2['Followers'].str.replace('[^\d]', ''), errors='coerce').astype(float).astype('Int64')

# %%
df_data2['Avg. Likes'] = pd.to_numeric(df_data2['Avg. Likes'].astype(str).str.replace('[^\d]', ''), errors='coerce').astype(float).astype('Int64')

# %%
df_data2['Posts'] = pd.to_numeric(df_data2['Posts'].astype(str).str.replace('[^\d]', ''), errors='coerce').astype(float).astype('Int64')

# %%
df_data2['Total Likes'] = pd.to_numeric(df_data2['Total Likes'].astype(str).str.replace('[^\d]', ''), errors='coerce').astype(float).astype('Int64')

# %%
df_data1.dtypes
# Out:
# Username                      object
# Channel Name                  object
# Country                       object
# Url                           object
# Main topic                    object
# Main video category           object
# Likes                        float64
# Likes Avg.                   float64
# Posts                          int64
# Followers                      int64
# Boost Index                    int64
# Comments Avg.                float64
# Views Avg.                   float64
# Avg. 1 Day                   float64
# Avg. 3 Day                   float64
# Avg. 7 Day                   float64
# Avg. 14 Day                  float64
# Avg. 30 Day                  float64
# Engagement Rate              float64
# Engagement Rate (60 Days)    float64
# dtype: object

# %%
df_data2.dtypes
# Out:
# Rank                     int64
# Channel Info            object
# Influence Score          int64
# Followers                Int64
# Avg. Likes               Int64
# Posts                    Int64
# 60-Day Eng Rate        float64
# New Post Avg. Likes     object
# Total Likes              Int64
# Country Or Region       object
# dtype: object

# %%
# Then, changing column names to match.

# %%
df_data1.rename(columns={
    'Likes': 'Total Likes',
    'Likes Avg.': 'Avg. Likes',
    'Engagement Rate (60 Days)': '60-Day Eng Rate',
    'Country': 'Country Or Region'
}, inplace=True)

# %%
df_data2.rename(columns={
    'Channel Info': 'Channel Name'
}, inplace=True)

# %%
df_data1
# Out:
#          Username  Channel Name Country Or Region  \
# 0       cristiano     cristiano                ES
# 1     kyliejenner   kyliejenner                US
# 2        leomessi      leomessi               NaN
# 3     selenagomez   selenagomez                US
# 4         therock       therock                US
# ..            ...           ...               ...
# 195   luansantana   luansantana                BR
# 196  danbilzerian  danbilzerian                CA
# 197     nickjonas     nickjonas                US
# 198  gururandhawa  gururandhawa                US
# 199     iambeckyg     iambeckyg                US
#
#                                         Url      Main topic  \
# 0       https://www.instagram.com/cristiano          Sports
# 1     https://www.instagram.com/kyliejenner             NaN
# 2        https://www.instagram.com/leomessi             NaN
# 3     https://www.instagram.com/selenagomez             NaN
# 4         https://www.instagram.com/therock             NaN
# ..                                      ...             ...
# 195   https://www.instagram.com/luansantana             NaN
# 196  https://www.instagram.com/danbilzerian  Pets & Animals
# 197     https://www.instagram.com/nickjonas             NaN
# 198  https://www.instagram.com/gururandhawa       Education
# 199     https://www.instagram.com/iambeckyg             NaN
#
#     Main video category   Total Likes    Avg. Likes  Posts  Followers  \
# 0                Sports  2.287645e+10  8.671953e+06   3328  465027234
# 1                   NaN  4.304855e+10  8.296736e+06   6921  356687629
# 2                   NaN  4.670492e+09  6.895178e+06    875  347032978
# 3                   NaN  8.442643e+09  6.252711e+06   1835  334551681
# 4                   NaN  9.562231e+09  1.874151e+06   6660  327064138
# ..                  ...           ...           ...    ...        ...
# 195                 NaN  1.121343e+08  2.055880e+05    714   33024460
# 196      Pets & Animals  2.355851e+09  2.044189e+06   1372   32938902
# 197                 NaN  1.364537e+09  7.442257e+05   2315   32906383
# 198           Education  1.039639e+09  6.377582e+05   2140   32845959
# 199                 NaN  1.033749e+09  6.254215e+05   2270   32812027
#
#      Boost Index  Comments Avg.    Views Avg.  Avg. 1 Day    Avg. 3 Day  \
# 0             92   51758.330927  1.700949e+07         NaN           NaN
# 1             91   47534.120961  2.287547e+07         NaN           NaN
# 2             90   47044.540305  1.176160e+07         NaN  4.810554e+06
# 3             93   39167.115727  1.072397e+07         NaN           NaN
# 4             91    8529.747043  5.413831e+06         NaN           NaN
# ..           ...            ...           ...         ...           ...
# 195           79    4795.100970  5.287625e+05         NaN  2.110623e+05
# 196           84   24680.813187  2.103653e+07         NaN  1.079742e+06
# 197           78    2191.083551  1.089024e+06         NaN  6.552600e+04
# 198           83    3837.251476  2.267251e+06         NaN  2.182120e+05
# 199           71    1588.418605  1.020376e+06         NaN  2.329310e+05
#
#        Avg. 7 Day   Avg. 14 Day   Avg. 30 Day  Engagement Rate  \
# 0    3.321113e+06  5.327340e+06  6.948659e+06         0.014916
# 1    1.223002e+06  2.196528e+06  4.692459e+06         0.017617
# 2    3.199807e+06  5.359469e+06  5.668454e+06         0.015534
# 3             NaN  2.340219e+06  2.340219e+06         0.013913
# 4    7.139700e+05  1.101339e+06  1.165227e+06         0.004426
# ..            ...           ...           ...              ...
# 195  1.293861e+05  1.938759e+05  1.824987e+05         0.005050
# 196  1.079742e+06  1.079742e+06  1.079742e+06         0.053036
# 197  6.552600e+04  6.552600e+04  3.396173e+05         0.017990
# 198  2.324327e+05  3.073671e+05  2.898926e+05         0.015257
# 199  3.001740e+05  3.218177e+05  3.962579e+05         0.014031
#
#      60-Day Eng Rate
# 0           0.015903
# 1           0.016189
# 2           0.019045
# 3           0.007720
# 4           0.003723
# ..               ...
# 195         0.005092
# 196         0.033629
# 197         0.010766
# 198         0.008365
# 199         0.016422
#
# [200 rows x 20 columns]

# %%
df_data2
# Out:
#      Rank           Channel Name  Influence Score  Followers  Avg. Likes  \
# 0       1            \ncristiano               92       <NA>        <NA>
# 1       2            kyliejenner               91       <NA>        <NA>
# 2       3             \nleomessi               90       <NA>        <NA>
# 3       4          \nselenagomez               93       <NA>        <NA>
# 4       5              \ntherock               91       <NA>        <NA>
# ..    ...                    ...              ...        ...         ...
# 195   196  \nkhabib_nurmagomedov               63       <NA>        <NA>
# 196   197         \ndanbilzerian               84       <NA>        <NA>
# 197   198            \nraisa6690               80       <NA>        <NA>
# 198   199          \nluansantana               79       <NA>        <NA>
# 199   200           \nnancyajram               81       <NA>        <NA>
#
#      Posts  60-Day Eng Rate New Post Avg. Likes  Total Likes Country Or Region
# 0     <NA>            0.013                6.3m         <NA>             Spain
# 1     <NA>            0.014                5.0m         <NA>     United States
# 2      915            0.010                3.5m         <NA>               NaN
# 3     <NA>            0.005                1.7m         <NA>     United States
# 4     <NA>            0.003              932.0k         <NA>     United States
# ..     ...              ...                 ...          ...               ...
# 195   <NA>            0.009              305.7k         <NA>            Russia
# 196   <NA>            0.064                2.1m         <NA>            Canada
# 197   <NA>            0.003              103.2k         <NA>         Indonesia
# 198    865            0.003               82.6k         <NA>            Brazil
# 199   <NA>            0.004              128.2k         <NA>            France
#
# [200 rows x 10 columns]

# %%
df_data1.dtypes
# Out:
# Username                object
# Channel Name            object
# Country Or Region       object
# Url                     object
# Main topic              object
# Main video category     object
# Total Likes            float64
# Avg. Likes             float64
# Posts                    int64
# Followers                int64
# Boost Index              int64
# Comments Avg.          float64
# Views Avg.             float64
# Avg. 1 Day             float64
# Avg. 3 Day             float64
# Avg. 7 Day             float64
# Avg. 14 Day            float64
# Avg. 30 Day            float64
# Engagement Rate        float64
# 60-Day Eng Rate        float64
# dtype: object

# %%
df_data2.dtypes
# Out:
# Rank                     int64
# Channel Name            object
# Influence Score          int64
# Followers                Int64
# Avg. Likes               Int64
# Posts                    Int64
# 60-Day Eng Rate        float64
# New Post Avg. Likes     object
# Total Likes              Int64
# Country Or Region       object
# dtype: object

# %%
# Combining the dataframes into a new dataframe.

# %%
# Converting 'Int64' to 'float64' in df_data2 for non-null values
df_data2['Followers'] = pd.to_numeric(df_data2['Followers'], errors='coerce')

# %%
# Convert 'Int64' to 'float64' in df_data2 for non-null values
df_data2['60-Day Eng Rate'] = pd.to_numeric(df_data2['60-Day Eng Rate'], errors='coerce').astype(float)

# %%
# Convert other 'Int64' columns to 'float64' in df_data2
df_data2['Avg. Likes'] = df_data2['Avg. Likes'].astype(float)
df_data2['Total Likes'] = df_data2['Total Likes'].astype(float)

# %%
df_data1[['Followers', 'Channel Name', 'Total Likes', 'Country Or Region', 'Avg. Likes', 'Posts', '60-Day Eng Rate']].dtypes
# Out:
# Followers              int64
# Channel Name          object
# Total Likes          float64
# Country Or Region     object
# Avg. Likes           float64
# Posts                  int64
# 60-Day Eng Rate      float64
# dtype: object

# %%
df_data2[['Followers', 'Channel Name', 'Total Likes', 'Country Or Region', 'Avg. Likes', 'Posts', '60-Day Eng Rate']].dtypes
# Out:
# Followers              Int64
# Channel Name          object
# Total Likes          float64
# Country Or Region     object
# Avg. Likes           float64
# Posts                  Int64
# 60-Day Eng Rate      float64
# dtype: object

# %%
df_data2['Followers'] = df_data2['Followers'].astype(float)

# %%
df_data2['Posts'] = df_data2['Posts'].astype(float)

# %%
# Creating "common colums" so that we can merge the columns and make a new dataset combining df1 and df2 with like columns being merged.

common_columns = ['Followers', 'Channel Name', 'Total Likes', 'Country Or Region', 'Avg. Likes', 'Posts', '60-Day Eng Rate']
merged_df = df_data1.merge(df_data2, how='outer', on=common_columns, suffixes=('_df1', '_df2'))

# %%
merged_df
# Out:
#         Username           Channel Name Country Or Region  \
# 0      cristiano              cristiano                ES
# 1    kyliejenner            kyliejenner                US
# 2       leomessi               leomessi               NaN
# 3    selenagomez            selenagomez                US
# 4        therock                therock                US
# ..           ...                    ...               ...
# 395          NaN  \nkhabib_nurmagomedov            Russia
# 396          NaN         \ndanbilzerian            Canada
# 397          NaN            \nraisa6690         Indonesia
# 398          NaN          \nluansantana            Brazil
# 399          NaN           \nnancyajram            France
#
#                                        Url Main topic Main video category  \
# 0      https://www.instagram.com/cristiano     Sports              Sports
# 1    https://www.instagram.com/kyliejenner        NaN                 NaN
# 2       https://www.instagram.com/leomessi        NaN                 NaN
# 3    https://www.instagram.com/selenagomez        NaN                 NaN
# 4        https://www.instagram.com/therock        NaN                 NaN
# ..                                     ...        ...                 ...
# 395                                    NaN        NaN                 NaN
# 396                                    NaN        NaN                 NaN
# 397                                    NaN        NaN                 NaN
# 398                                    NaN        NaN                 NaN
# 399                                    NaN        NaN                 NaN
#
#       Total Likes    Avg. Likes   Posts    Followers  Boost Index  \
# 0    2.287645e+10  8.671953e+06  3328.0  465027234.0         92.0
# 1    4.304855e+10  8.296736e+06  6921.0  356687629.0         91.0
# 2    4.670492e+09  6.895178e+06   875.0  347032978.0         90.0
# 3    8.442643e+09  6.252711e+06  1835.0  334551681.0         93.0
# 4    9.562231e+09  1.874151e+06  6660.0  327064138.0         91.0
# ..            ...           ...     ...          ...          ...
# 395           NaN           NaN     NaN          NaN          NaN
# 396           NaN           NaN     NaN          NaN          NaN
# 397           NaN           NaN     NaN          NaN          NaN
# 398           NaN           NaN   865.0          NaN          NaN
# 399           NaN           NaN     NaN          NaN          NaN
#
#      Comments Avg.    Views Avg.  Avg. 1 Day  Avg. 3 Day  Avg. 7 Day  \
# 0     51758.330927  1.700949e+07         NaN         NaN   3321113.0
# 1     47534.120961  2.287547e+07         NaN         NaN   1223002.0
# 2     47044.540305  1.176160e+07         NaN   4810554.0   3199807.0
# 3     39167.115727  1.072397e+07         NaN         NaN         NaN
# 4      8529.747043  5.413831e+06         NaN         NaN    713970.0
# ..             ...           ...         ...         ...         ...
# 395            NaN           NaN         NaN         NaN         NaN
# 396            NaN           NaN         NaN         NaN         NaN
# 397            NaN           NaN         NaN         NaN         NaN
# 398            NaN           NaN         NaN         NaN         NaN
# 399            NaN           NaN         NaN         NaN         NaN
#
#       Avg. 14 Day   Avg. 30 Day  Engagement Rate  60-Day Eng Rate   Rank  \
# 0    5.327340e+06  6.948659e+06         0.014916         0.015903    NaN
# 1    2.196528e+06  4.692459e+06         0.017617         0.016189    NaN
# 2    5.359469e+06  5.668454e+06         0.015534         0.019045    NaN
# 3    2.340219e+06  2.340219e+06         0.013913         0.007720    NaN
# 4    1.101339e+06  1.165227e+06         0.004426         0.003723    NaN
# ..            ...           ...              ...              ...    ...
# 395           NaN           NaN              NaN         0.009000  196.0
# 396           NaN           NaN              NaN         0.064000  197.0
# 397           NaN           NaN              NaN         0.003000  198.0
# 398           NaN           NaN              NaN         0.003000  199.0
# 399           NaN           NaN              NaN         0.004000  200.0
#
#      Influence Score New Post Avg. Likes
# 0                NaN                 NaN
# 1                NaN                 NaN
# 2                NaN                 NaN
# 3                NaN                 NaN
# 4                NaN                 NaN
# ..               ...                 ...
# 395             63.0              305.7k
# 396             84.0                2.1m
# 397             80.0              103.2k
# 398             79.0               82.6k
# 399             81.0              128.2k
#
# [400 rows x 23 columns]

# %%
merged_df.dtypes
# Out:
# Username                object
# Channel Name            object
# Country Or Region       object
# Url                     object
# Main topic              object
# Main video category     object
# Total Likes            float64
# Avg. Likes             float64
# Posts                  float64
# Followers              float64
# Boost Index            float64
# Comments Avg.          float64
# Views Avg.             float64
# Avg. 1 Day             float64
# Avg. 3 Day             float64
# Avg. 7 Day             float64
# Avg. 14 Day            float64
# Avg. 30 Day            float64
# Engagement Rate        float64
# 60-Day Eng Rate        float64
# Rank                   float64
# Influence Score        float64
# New Post Avg. Likes     object
# dtype: object

# %%
merged_df.shape
# Out:
# (400, 23)

# %%
# checking for nulls

# %%
merged_df.isnull().sum()
# Out:
# Username               200
# Channel Name             0
# Country Or Region      125
# Url                    200
# Main topic             270
# Main video category    267
# Total Likes            200
# Avg. Likes             200
# Posts                  146
# Followers              200
# Boost Index            200
# Comments Avg.          200
# Views Avg.             203
# Avg. 1 Day             339
# Avg. 3 Day             275
# Avg. 7 Day             238
# Avg. 14 Day            214
# Avg. 30 Day            205
# Engagement Rate        200
# 60-Day Eng Rate          0
# Rank                   200
# Influence Score        200
# New Post Avg. Likes    200
# dtype: int64

# %% [markdown]
# ###### ** Since we are not modeling, I am not going to handle the nulls by replacing them with values.
# ###### ** Instead, I am going to do some EDA t see if I notice any cool trends that I'd want to chart in Tableau and then I'll move into working on the Tableau Dash.

# %%
# Saving new dataframe

# %%
merged_df.to_csv('new_df.csv')

# %%
merged_df.shape
# Out:
# (400, 23)

# %% [markdown]
# #### Part III: Exploratory Data Analysis

# %%
# Total Likes Distribution Plot:

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=merged_df,
             x='Total Likes',
            color = 'orange');

plt.title('Distribution of Total Likes')
plt.show()

plt.savefig('images/distributionoftotallikes.png')

# %%
# Avg. Likes Distribution Plot:

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=merged_df,
             x='Avg. Likes',
            color ='orange');

plt.title('Distribution of Avg. Likes')
plt.show()

plt.savefig('images/distributionofavglikes.png')

# %%
# Posts Distribution Plot:

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=merged_df,
             x='Posts',
            color ='orange');

plt.title('Distribution of Posts')
plt.show()

plt.savefig('images/distributionofposts.png')

# %%
# Followers Distribution Plot:

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=merged_df,
             x='Followers',
            color ='orange');

plt.title('Distribution of Followers')
plt.show()

plt.savefig('images/distributionoffollowers.png')

# %%
# Boost Index Distribution Plot:

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=merged_df,
             x='Boost Index',
            color ='orange');

plt.title('Distribution of Boost Index')
plt.show()

plt.savefig('images/distributionofboostindex.png')

# %%
# Comments Avg. Distribution Plot:

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=merged_df,
             x='Comments Avg.',
            color ='orange');

plt.title('Distribution of Comments Avg.')
plt.show()

plt.savefig('images/distributionofcommentsavg.png')

# %%
# Views Avg. Distribution Plot:

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=merged_df,
             x='Views Avg.',
             color='orange')  # Set the color to orange

plt.title('Distribution of Views Avg.')
plt.savefig('images/distributionofviewsavg.png')
plt.show()

# %%
# Engagement Rate Distribution Plot:

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=merged_df,
             x='Engagement Rate',
            color ='orange');

plt.title('Distribution of Engagement Rate')
plt.show()

plt.savefig('images/distributionofengagementrate.png')

# %%
# 60-Day Eng Rate Distribution Plot:

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=merged_df,
             x='60-Day Eng Rate',
            color ='orange');

plt.title('Distribution of 60-Day Eng Rate')
plt.show()

plt.savefig('images/distributionof60dayengrate.png')

# %%
# Influence Score Distribution Plot:

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=merged_df,
             x='Influence Score',
            color ='orange');
             
plt.title('Distribution of Influence Score')
plt.show()

plt.savefig('images/distributionofinfluencescore.png')

# %%
# Correlation Heatmap

# %%
numeric_columns = merged_df.select_dtypes(include=['float64', 'int64'])

plt.figure(figsize=(12, 10))

numeric_columns = merged_df.select_dtypes(include=['float64', 'int64'])

corr_matrix = numeric_columns.corr()

sns.heatmap(corr_matrix,
            annot=True,
            cmap='YlOrRd',  # Set the colormap to Yellow-Orange-Red
            linewidths=0.5)

plt.title('Correlation Heatmap')
plt.savefig('images/correlationheatmap.png')
plt.show()

# %%
# Count Plot Country Or Region

# %%
plt.figure(figsize=(12, 6))

sns.countplot(data=merged_df, x='Country Or Region',
              order=merged_df['Country Or Region'].value_counts().index,
              palette='Oranges');

plt.title('Count of Influencers by Country Or Region')

plt.xticks(rotation=90)
plt.show()

plt.savefig('images/countofinfluencersbycountry.png')

# %%
# Realizing I need to combine some of these value counts as the abbrevition can be merged with the country name in a lot of cases.

# %%
unique_countries = merged_df['Country Or Region'].unique()

# %%
unique_countries
# Out:
# array(['ES', 'US', nan, 'CA', 'BR', 'NL', 'GB', 'IN', 'UY', 'TR', 'ID',
#        'CO', 'FR', 'AU', 'IT', 'AE', 'PR', 'CI', 'AI', 'CH', 'SE', 'CZ',
#        'VG', 'MX', 'RU', 'DE', 'Spain', 'United States', 'Canada',
#        'Brazil', 'Netherlands', 'United Kingdom', 'India', 'Uruguay',
#        'Turkey', 'Indonesia', 'Colombia', 'France', 'Australia', 'Italy',
#        'United Arab Emirates', 'Puerto Rico', "Côte d'Ivoire", 'Anguilla',
#        'Switzerland', 'Sweden', 'British Virgin Islands',
#        'Czech Republic', 'Mexico', 'Germany', 'Russia'], dtype=object)

# %%
reverse_country_mapping = {
    'US': 'United States',
    'ES': 'Spain',
    'CA': 'Canada',
    'BR': 'Brazil',
    'NL': 'Netherlands',
    'GB': 'United Kingdom',
    'IN': 'India',
    'UY': 'Uruguay',
    'TR': 'Turkey',
    'ID': 'Indonesia',
    'CO': 'Columbia',
    'FR': 'France',
    'AU': 'Australia',
    'IT': 'Italy',
    'AE': 'United Arab Emirates',
    'PR': 'Puerto Rico',
    "CI": "Côte d'Ivoire",
    'AI': 'Anguilla',
    'CH': 'Switzerland',
    'SE': 'Sweden',
    'CZ': 'Czechia',
    'VG': 'British Virgin Islands',
    'MX': 'Mexico',
    'RU': 'Russia',
    'DE': 'Germany'}

# %%
merged_df['Country Or Region'] = merged_df['Country Or Region'].replace(reverse_country_mapping)

# %%
unique_countries = merged_df['Country Or Region'].unique()

# %%
unique_countries
# Out:
# array(['Spain', 'United States', nan, 'Canada', 'Brazil', 'Netherlands',
#        'United Kingdom', 'India', 'Uruguay', 'Turkey', 'Indonesia',
#        'Columbia', 'France', 'Australia', 'Italy', 'United Arab Emirates',
#        'Puerto Rico', "Côte d'Ivoire", 'Anguilla', 'Switzerland',
#        'Sweden', 'Czechia', 'British Virgin Islands', 'Mexico', 'Russia',
#        'Germany', 'Colombia', 'Czech Republic'], dtype=object)

# %%
# Realizing I should probably do the same thing for influencer channel names if needed

# %%
unique_influencers = merged_df['Channel Name'].unique()

# %%
unique_influencers
# Out:
# array(['cristiano', 'kyliejenner', 'leomessi', 'selenagomez', 'therock',
#        'kimkardashian', 'arianagrande', 'beyonce', 'khloekardashian',
#        'kendalljenner', 'justinbieber', 'natgeo', 'nike', 'taylorswift',
#        'jlo', 'virat.kohli', 'nickiminaj', 'kourtneykardash',
#        'mileycyrus', 'neymarjr', 'katyperry', 'kevinhart4real', 'zendaya',
#        'iamcardib', 'ddlovato', 'badgalriri', 'kingjames', 'theellenshow',
#        'realmadrid', 'champagnepapi', 'chrisbrownofficial', 'fcbarcelona',
#        'billieeilish', 'dualipa', 'gal_gadot', 'vindiesel',
#        'priyankachopra', 'lalalalisa_m', 'nasa', 'Shakira', 'gigihadid',
#        'snoopdogg', 'davidbeckham', 'shraddhakapoor', 'victoriassecret',
#        'k.mbappe', 'nehakakkar', 'shawnmendes', 'nba', 'narendramodi',
#        'jennierubyjane', 'deepikapadukone', 'tomholland2013',
#        'aliaabhatt', 'ronaldinho', 'emmawatson', 'bts.bighitofficial',
#        'katrinakaif', 'justintimberlake', 'marvel', 'camila_cabello',
#        'willsmith', 'raffinagita1717', 'anitta', 'maluma', 'akshaykumar',
#        'jacquelinef143', 'sooyaaa__', 'psg', 'roses_are_rosie',
#        'anushkasharma', 'manchesterunited', 'whinderssonnunes', '9gag',
#        'marcelotwelve', 'karimbenzema', 'chrishemsworth', 'paulpogba',
#        'iamzlatanibrahimovic', 'karolg', 'leonardodicaprio',
#        'milliebobbybrown', 'juventus', 'zacefron', 'tatawerneck',
#        'bellahadid', 'robertdowneyjr', 'sunnyleone', 'ladygaga',
#        'beingsalmankhan', 'jbalvin', 'sergioramos', 'ayutingting92',
#        'dishapatani', 'mosalah', '433', 'hudabeauty', 'adele',
#        'michelleobama', 'jamesrodriguez10', 'kritisanon', 'krisjenner',
#        'lelepons', 'charlidamelio', 'gucci', 'louisvuitton',
#        'prillylatuconsina96', 'dovecameron', 'garethbale11',
#        'paulodybala', 'blackpinkofficial', 'jokowi', 'nusr_et',
#        '5-Minute Crafts GIRLY', 'vanessahudgens', 'thv', 'harrystyles',
#        'zayn', 'larissamanoela', 'haileybieber', 'thenotoriousmma',
#        'daddyyankee', 'travisscott', 'natgeotravel', 'nikefootball',
#        'stephencurry30', 'vancityreynolds', 'luissuarez9', 'maisa',
#        'gusttavolima', 'hrithikroshan', 'nickyjampr', 'jannatzubair29',
#        'varundvn', 'brunamarquezine', 'caradelevingne', 'buzzfeedtasty',
#        'kapilsharma', 'britneyspears', 'mariliamendoncacantora',
#        'badbunnypr', 'dior', 'norafatehi', 'jenniferaniston',
#        'marinaruybarbosa', 'addisonraee', 'theweeknd', 'ranveersingh',
#        'andresiniesta8', 'princessyahrini', 'liverpoolfc', 'teddysphotos',
#        'georginagio', 'natashawilona12', 'ruben_onsu', 'mahi7781',
#        'chrissyteigen', 'hm', 'wizkhalifa', 'j.m', 'anushkasen0408',
#        'worldstar', 'prattprattpratt', 'marvelstudios', 'wesleysafadao',
#        'parineetichopra', 'cznburak', 'laudyacynthiabella',
#        'antogriezmann', 'gisel_la', 'eminem', 'rkive', 'colesprouse',
#        'nattinatasha', 'mercedesbenz', 'tigerjackieshroff', 'barackobama',
#        'shahidkapoor', 'kimberly.loaiza', 'sachintendulkar', 'simoneses',
#        'ivetesangalo', 'paollaoliveirareal', 'lunamaya', 'dannapaola',
#        'blakelively', 'toni.kr8s', 'adidasoriginals', 'disney',
#        'shaymitchell', 'khabib_nurmagomedov', 'bmw', 'zidane',
#        'nancyajram', 'sonamkapoor', 'luansantana', 'danbilzerian',
#        'nickjonas', 'gururandhawa', 'iambeckyg', '\ncristiano',
#        '\nleomessi', '\nselenagomez', '\ntherock', '\narianagrande',
#        '\nkimkardashian', '\nbeyonce', '\nkhloekardashian',
#        '\njustinbieber', '\nkendalljenner', '\nnatgeo', '\nnike',
#        '\ntaylorswift', '\njlo', '\nvirat.kohli', '\nnickiminaj',
#        '\nkourtneykardash', '\nmileycyrus', '\nneymarjr', '\nkatyperry',
#        '\nkevinhartreal', '\nzendaya', '\niamcardib', '\nddlovato',
#        '\nbadgalriri', '\nkingjames', '\nrealmadrid', '\ntheellenshow',
#        '\nchampagnepapi', '\nchrisbrownofficial', '\nfcbarcelona',
#        '\nbillieeilish', '\ngal_gadot', '\ndualipa', '\nvindiesel',
#        '\nnasa', '\npriyankachopra', '\nlalalalisa_m', '\nsnoopdogg',
#        '\nShakira', '\ngigihadid', '\ndavidbeckham', '\nshraddhakapoor',
#        '\nvictoriassecret', '\nk.mbappe', '\nnehakakkar', '\naliaabhatt',
#        '\nnba', '\njennierubyjane', '\nshawnmendes', '\nnarendramodi',
#        '\ndeepikapadukone', '\nronaldinho', '\ntomholland2013',
#        '\nbts.bighitofficial', '\nemmawatson', '\nkatrinakaif',
#        '\nmarvel', '\njustintimberlake', '\ncamila_cabello',
#        '\nsooyaaa__', '\nraffinagita1717', '\njacquelinef143',
#        '\nroses_are_rosie', '\nakshaykumar', '\nwillsmith', '\nanitta',
#        '\nmaluma', '\npsg', '\nmanchesterunited', '\nanushkasharma',
#        '\nmarcelotwelve', '\nwhinderssonnunes', '\nmilliebobbybrown',
#        '\nkarimbenzema', '\ngag', '\nkarolg', '\nchrishemsworth',
#        '\niamzlatanibrahimovic', '\npaulpogba', '\nzacefron',
#        '\njuventus', '\nbellahadid', '\nleonardodicaprio',
#        '\nbeingsalmankhan', '\ntatawerneck', '\nsunnyleone',
#        '\ndishapatani', '\nsergioramos', '\nladygaga', '\nrobertdowneyjr',
#        '\nmosalah', '\njbalvin', '\nayutingting92', '\nthv',
#        '\nhudabeauty', '\nmichelleobama', '\nkritisanon', '\nadele',
#        '\nkrisjenner', '\njamesrodriguez10', '\nblackpinkofficial',
#        '\nlelepons', '\nprillylatuconsina96', '\ncharlidamelio',
#        '\ngucci', '\npaulodybala', '\nlouisvuitton', '\ndovecameron',
#        '\njokowi', '\nhaileybieber', '\nnusr_et', '\ngarethbale',
#        '\nharrystyles', '\nvanessahudgens', '\nlarissamanoela', '\nzayn',
#        '\ntravisscott', '\nstephencurry30', '\n5-Minute Crafts GIRLY',
#        '\nthenotoriousmma', '\ndaddyyankee', '\nnatgeotravel',
#        '\nvancityreynolds', '\nnikefootball', '\nmaisa',
#        '\njannatzubair29', '\nluissuarez9', '\nvarundvn', '\nj.m',
#        '\nhrithikroshan', '\ngusttavolima', '\ntheweeknd', '\nnickyjampr',
#        '\nbuzzfeedtasty', '\nbrunamarquezine', '\nbadbunnypr',
#        '\nkapilsharma', '\ncaradelevingne', '\nnorafatehi',
#        '\nbritneyspears', '\nmariliamendoncacantora', '\ndior',
#        '\ncznburak', '\nranveersingh', '\nmarinaruybarbosa',
#        '\njenniferaniston', '\nruben_onsu', '\nliverpoolfc',
#        '\nteddysphotos', '\nprincessyahrini', '\nandresiniesta8',
#        '\naddisonraee', '\nnatashawilona12', '\nmahi7781',
#        '\nchrissyteigen', '\nworldstar', '\ngeorginagio', '\nwizkhalifa',
#        '\nprattprattpratt', '\nhm', '\nmarvelstudios', '\nrkive',
#        '\nparineetichopra', '\nwesleysafadao', '\nlaudyacynthiabella',
#        '\ngisel_la', '\nantogriezmann', '\neminem', '\nmercedesbenz',
#        '\nsachintendulkar', '\nnattinatasha', '\nkimberly.loaiza',
#        '\nshahidkapoor', '\ntigerjackieshroff', '\nblakelively',
#        '\ncolesprouse', '\nsimonemendes', '\ntoni.krs', '\nlunamaya',
#        '\nbarackobama', '\nivetesangalo', '\npaollaoliveirareal',
#        '\ndannapaola', '\ndisney', '\nshaymitchell', '\nadidasoriginals',
#        '\nzidane', '\nbmw', '\niambeckyg', '\nrashmika_mandanna',
#        '\nsonamkapoor', '\nkhabib_nurmagomedov', '\ndanbilzerian',
#        '\nraisa6690', '\nluansantana', '\nnancyajram'], dtype=object)

# %%
# Removing leading whitespaces and standardizing capitalization
merged_df['Channel Name'] = merged_df['Channel Name'].str.strip().str.lower()

# %%
# Checking for unique usernames after standardization
unique_usernames = merged_df['Channel Name'].unique()
unique_usernames
# Out:
# array(['cristiano', 'kyliejenner', 'leomessi', 'selenagomez', 'therock',
#        'kimkardashian', 'arianagrande', 'beyonce', 'khloekardashian',
#        'kendalljenner', 'justinbieber', 'natgeo', 'nike', 'taylorswift',
#        'jlo', 'virat.kohli', 'nickiminaj', 'kourtneykardash',
#        'mileycyrus', 'neymarjr', 'katyperry', 'kevinhart4real', 'zendaya',
#        'iamcardib', 'ddlovato', 'badgalriri', 'kingjames', 'theellenshow',
#        'realmadrid', 'champagnepapi', 'chrisbrownofficial', 'fcbarcelona',
#        'billieeilish', 'dualipa', 'gal_gadot', 'vindiesel',
#        'priyankachopra', 'lalalalisa_m', 'nasa', 'shakira', 'gigihadid',
#        'snoopdogg', 'davidbeckham', 'shraddhakapoor', 'victoriassecret',
#        'k.mbappe', 'nehakakkar', 'shawnmendes', 'nba', 'narendramodi',
#        'jennierubyjane', 'deepikapadukone', 'tomholland2013',
#        'aliaabhatt', 'ronaldinho', 'emmawatson', 'bts.bighitofficial',
#        'katrinakaif', 'justintimberlake', 'marvel', 'camila_cabello',
#        'willsmith', 'raffinagita1717', 'anitta', 'maluma', 'akshaykumar',
#        'jacquelinef143', 'sooyaaa__', 'psg', 'roses_are_rosie',
#        'anushkasharma', 'manchesterunited', 'whinderssonnunes', '9gag',
#        'marcelotwelve', 'karimbenzema', 'chrishemsworth', 'paulpogba',
#        'iamzlatanibrahimovic', 'karolg', 'leonardodicaprio',
#        'milliebobbybrown', 'juventus', 'zacefron', 'tatawerneck',
#        'bellahadid', 'robertdowneyjr', 'sunnyleone', 'ladygaga',
#        'beingsalmankhan', 'jbalvin', 'sergioramos', 'ayutingting92',
#        'dishapatani', 'mosalah', '433', 'hudabeauty', 'adele',
#        'michelleobama', 'jamesrodriguez10', 'kritisanon', 'krisjenner',
#        'lelepons', 'charlidamelio', 'gucci', 'louisvuitton',
#        'prillylatuconsina96', 'dovecameron', 'garethbale11',
#        'paulodybala', 'blackpinkofficial', 'jokowi', 'nusr_et',
#        '5-minute crafts girly', 'vanessahudgens', 'thv', 'harrystyles',
#        'zayn', 'larissamanoela', 'haileybieber', 'thenotoriousmma',
#        'daddyyankee', 'travisscott', 'natgeotravel', 'nikefootball',
#        'stephencurry30', 'vancityreynolds', 'luissuarez9', 'maisa',
#        'gusttavolima', 'hrithikroshan', 'nickyjampr', 'jannatzubair29',
#        'varundvn', 'brunamarquezine', 'caradelevingne', 'buzzfeedtasty',
#        'kapilsharma', 'britneyspears', 'mariliamendoncacantora',
#        'badbunnypr', 'dior', 'norafatehi', 'jenniferaniston',
#        'marinaruybarbosa', 'addisonraee', 'theweeknd', 'ranveersingh',
#        'andresiniesta8', 'princessyahrini', 'liverpoolfc', 'teddysphotos',
#        'georginagio', 'natashawilona12', 'ruben_onsu', 'mahi7781',
#        'chrissyteigen', 'hm', 'wizkhalifa', 'j.m', 'anushkasen0408',
#        'worldstar', 'prattprattpratt', 'marvelstudios', 'wesleysafadao',
#        'parineetichopra', 'cznburak', 'laudyacynthiabella',
#        'antogriezmann', 'gisel_la', 'eminem', 'rkive', 'colesprouse',
#        'nattinatasha', 'mercedesbenz', 'tigerjackieshroff', 'barackobama',
#        'shahidkapoor', 'kimberly.loaiza', 'sachintendulkar', 'simoneses',
#        'ivetesangalo', 'paollaoliveirareal', 'lunamaya', 'dannapaola',
#        'blakelively', 'toni.kr8s', 'adidasoriginals', 'disney',
#        'shaymitchell', 'khabib_nurmagomedov', 'bmw', 'zidane',
#        'nancyajram', 'sonamkapoor', 'luansantana', 'danbilzerian',
#        'nickjonas', 'gururandhawa', 'iambeckyg', 'kevinhartreal', 'gag',
#        'garethbale', 'simonemendes', 'toni.krs', 'rashmika_mandanna',
#        'raisa6690'], dtype=object)

# %%
# Separate operations for numerical and string columns
num_columns = merged_df.select_dtypes(include=['number']).columns

# Perform sum() for numerical columns
num_df = merged_df.groupby('Channel Name')[num_columns].sum().reset_index()

# Handle string columns separately
str_df = merged_df.groupby('Channel Name')['Country Or Region'].first().reset_index()

# Merge the results
new_merged_df = pd.merge(num_df, str_df, on='Channel Name')

# Replace zeros with nulls
new_merged_df = new_merged_df.replace(0, np.nan)

# %%
new_merged_df
# Out:
#               Channel Name   Total Likes    Avg. Likes    Posts    Followers  \
# 0                      433  7.235187e+09  8.634482e+05  10319.0   50846051.0
# 1    5-minute crafts girly  1.741363e+09  1.574992e+05  14519.0   46618064.0
# 2                     9gag  5.062668e+09  6.787113e+05  10021.0   58181054.0
# 3              addisonraee  7.312062e+08  3.150451e+06    626.0   40402560.0
# 4                    adele  1.411416e+09  4.739484e+06    841.0   50542177.0
# ..                     ...           ...           ...      ...          ...
# 202              worldstar  1.158924e+10  1.575462e+05  99022.0   37818287.0
# 203               zacefron  1.081307e+09  2.262104e+06   1332.0   53887887.0
# 204                   zayn  5.701936e+08  4.713926e+06    327.0   46197756.0
# 205                zendaya  1.472709e+10  5.744110e+06   3537.0  147816903.0
# 206                 zidane  3.022443e+08  1.059596e+06    743.0   33177179.0
#
#      Boost Index  Comments Avg.    Views Avg.  Avg. 1 Day    Avg. 3 Day  \
# 0           79.0    4092.410533  3.232600e+06   519454.20  6.609231e+05
# 1           85.0     342.393615  1.289002e+06         NaN  9.366600e+03
# 2           86.0    5559.041481  3.613240e+06   202474.75  2.274771e+05
# 3           85.0    8362.427152  6.400652e+06         NaN  1.349907e+06
# 4           84.0   32030.802817  1.539618e+07         NaN  2.211066e+06
# ..           ...            ...           ...         ...           ...
# 202         78.0    2493.199621  1.056852e+06    35157.00  5.258280e+04
# 203         86.0    9847.057143  5.708581e+06         NaN           NaN
# 204         82.0   69133.050000  8.478670e+06         NaN           NaN
# 205         87.0   16106.142857  7.685348e+06         NaN           NaN
# 206         41.0    6400.405660  1.691815e+06         NaN  9.991030e+05
#
#        Avg. 7 Day   Avg. 14 Day   Avg. 30 Day  Engagement Rate  \
# 0    6.962332e+05  7.306245e+05  8.104614e+05         0.013870
# 1    1.067833e+04  1.429065e+04  1.392567e+04         0.002579
# 2    2.217436e+05  2.585828e+05  2.689793e+05         0.008779
# 3    1.009004e+06  1.026147e+06  1.214530e+06         0.060824
# 4    2.766306e+06  2.392644e+06  2.392644e+06         0.067521
# ..            ...           ...           ...              ...
# 202  7.420832e+04  7.268365e+04  7.153115e+04         0.003166
# 203           NaN           NaN           NaN         0.030471
# 204  4.037963e+06  4.037963e+06  3.600000e+06         0.077751
# 205  3.970268e+06  3.958943e+06  4.755622e+06         0.028354
# 206  9.991030e+05  9.991030e+05  9.118223e+05         0.025347
#
#      60-Day Eng Rate   Rank  Influence Score Country Or Region
# 0           0.035295   96.0             79.0       Netherlands
# 1           0.001340  122.0             85.0     United States
# 2           0.004668    NaN              NaN     United States
# 3           0.055012  155.0             85.0              None
# 4           0.092149  101.0             84.0     United States
# ..               ...    ...              ...               ...
# 202         0.003961  159.0             78.0     United States
# 203         0.052730   82.0             86.0     United States
# 204         0.169353  119.0             82.0     United States
# 205         0.105179   23.0             87.0     United States
# 206         0.042136  191.0             41.0            France
#
# [207 rows x 18 columns]

# %%
new_merged_df.to_csv('final_influencers_new_merged_df.csv')

# %%
# Count Plot Main video category:

# %%
plt.figure(figsize=(12, 6))

sns.countplot(data=merged_df,
              x='Main video category',
              order=merged_df['Main video category'].value_counts().index,
              palette='Oranges');
              
plt.title('Count of Influencers by Main Video Category')
              
plt.xticks(rotation=45)
plt.show()

plt.savefig('images/countofinfluencersbymainvideocategory.png')

# %%
# Count Plot Main topic:

# %%
plt.figure(figsize=(12, 6))

sns.countplot(data=merged_df,
              x='Main topic',
              order=merged_df['Main topic'].value_counts().index,
              palette='Oranges')

plt.title('Count of Influencers by Main Topic')

plt.xticks(rotation=45)
plt.show()

plt.savefig('images/countofinfluencersbymaintopic.png')

# %%
# Box Plot Total Likes:

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(data=merged_df,
            y='Total Likes',
           color = 'orange')

plt.title('Boxplot of Total Likes')
plt.show()

plt.savefig('images/boxplotoftotallikes.png')

# %%
# Box Plot Avg. Likes:

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(data=merged_df,
            y='Avg. Likes',
           color = 'orange')

plt.title('Boxplot of Avg. Likes')
plt.show()

plt.savefig('images/boxplotofavglikes.png')

# %%
# Box Plot Posts:

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(data=merged_df,
            y='Posts',
           color = 'orange')

plt.title('Boxplot of Posts')
plt.show()

plt.savefig('images/boxplotofposts.png')

# %%
# Box Plot Followers:

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(data=merged_df,
            y='Followers',
           color = 'orange')

plt.title('Followers')
plt.show()

plt.savefig('images/boxplotoffollowers.png')

# %%
# Box Plot Boost Index:

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(data=merged_df,
            y='Boost Index',
           color = 'orange')

plt.title('Box Plot Of Boost Index')
plt.show()

plt.savefig('images/boxplotofboostindex.png')

# %%
# Box Plot Comments Avg:

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(data=merged_df,
            y='Comments Avg.',
           color = 'orange')

plt.title('Box Plot Of Comments')
plt.show()

plt.savefig('images/boxplotofcomments.png')

# %%
# Box Plot Views Avg:

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(data=merged_df,
            y='Views Avg.',
           color = 'orange')

plt.title('Box Plot Of Views')
plt.show()

plt.savefig('images/boxplotofviews.png')

# %% [markdown]
# #### Part III: Tableau Dash (see Tableau)
